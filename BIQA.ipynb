# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/adifatol/BIQA/blob/master/BIQA.ipynb)

# %%
# !ls jpeg
# Out:
# ls: cannot access 'jpeg': No such file or directory

# %% [markdown]
# # Upload Images
#
# shows a dialog to upload new images
#
# option to download the CSIQ Image Quality Database

# %%
# from google.colab import files

# uploaded = files.upload()

# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))

# %%
# !wget http://vision.eng.shizuoka.ac.jp/csiq/src_imgs.zip
# !wget http://vision.eng.shizuoka.ac.jp/csiq/dst_imgs.zip
  
# !unzip src_imgs.zip
# !unzip dst_imgs.zip
# Out:
# --2018-07-27 13:47:24--  http://vision.eng.shizuoka.ac.jp/csiq/src_imgs.zip
# Resolving vision.eng.shizuoka.ac.jp (vision.eng.shizuoka.ac.jp)... 133.70.150.170
# Connecting to vision.eng.shizuoka.ac.jp (vision.eng.shizuoka.ac.jp)|133.70.150.170|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14455692 (14M) [application/zip]
# Saving to: ‘src_imgs.zip’
#
# src_imgs.zip        100%[===================>]  13.79M  6.27MB/s    in 2.2s
#
# 2018-07-27 13:47:27 (6.27 MB/s) - ‘src_imgs.zip’ saved [14455692/14455692]
#
# --2018-07-27 13:47:28--  http://vision.eng.shizuoka.ac.jp/csiq/dst_imgs.zip
# Resolving vision.eng.shizuoka.ac.jp (vision.eng.shizuoka.ac.jp)... 133.70.150.170
# Connecting to vision.eng.shizuoka.ac.jp (vision.eng.shizuoka.ac.jp)|133.70.150.170|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 374383009 (357M) [application/zip]
# Saving to: ‘dst_imgs.zip’
#
# dst_imgs.zip         55%[==========>         ] 199.76M  11.2MB/s    eta 15s
# dst_imgs.zip        100%[===================>] 357.04M  11.2MB/s    in 33s
#
# 2018-07-27 13:48:01 (10.9 MB/s) - ‘dst_imgs.zip’ saved [374383009/374383009]
#
# Archive:  src_imgs.zip
#   inflating: 1600.png
#   inflating: aerial_city.png
#   inflating: boston.png
#   inflating: bridge.png
#   inflating: butter_flower.png
#   inflating: cactus.png
#   inflating: child_swimming.png
#   inflating: couple.png
#   inflating: elk.png
#   inflating: family.png
#   inflating: fisher.png
#   inflating: foxy.png
#   inflating: geckos.png
#   inflating: lady_liberty.png
#   inflating: lake.png
#   inflating: log_seaside.png
#   inflating: monument.png
#   inflating: native_american.png
#   inflating: redwood.png
#   inflating: roping.png
#   inflating: rushmore.png
#   inflating: shroom.png
#   inflating: snow_leaves.png
#   inflating: sunset_sparrow.png
#   inflating: sunsetcolor.png
#   inflating: swarm.png
#   inflating: trolley.png
#   inflating: turtle.png
#   inflating: veggies.png
#   inflating: woman.png
# Archive:  dst_imgs.zip
#   inflating: jpeg2000/1600.jpeg2000.1.png
#   inflating: jpeg2000/1600.jpeg2000.2.png
#   inflating: jpeg2000/1600.jpeg2000.3.png
#   inflating: jpeg2000/1600.jpeg2000.4.png
#   inflating: jpeg2000/1600.jpeg2000.5.png
#   inflating: jpeg2000/aerial_city.jpeg2000.1.png
#   inflating: jpeg2000/aerial_city.jpeg2000.2.png
#   inflating: jpeg2000/aerial_city.jpeg2000.3.png
#   inflating: jpeg2000/aerial_city.jpeg2000.4.png
#   inflating: jpeg2000/aerial_city.jpeg2000.5.png
#   inflating: blur/boston.BLUR.1.png
#   inflating: blur/boston.BLUR.2.png
#   inflating: blur/boston.BLUR.3.png
#   inflating: blur/boston.BLUR.4.png
#   inflating: blur/boston.BLUR.5.png
#   inflating: blur/bridge.BLUR.1.png
#   inflating: blur/bridge.BLUR.2.png
#   inflating: blur/bridge.BLUR.3.png
#   inflating: blur/bridge.BLUR.4.png
#   inflating: blur/bridge.BLUR.5.png
#   inflating: blur/butter_flower.BLUR.1.png
#   inflating: blur/butter_flower.BLUR.2.png
#   inflating: blur/butter_flower.BLUR.3.png
#   inflating: blur/butter_flower.BLUR.4.png
#   inflating: blur/butter_flower.BLUR.5.png
#   inflating: blur/cactus.BLUR.1.png
#   inflating: blur/cactus.BLUR.2.png
#   inflating: blur/cactus.BLUR.3.png
#   inflating: blur/cactus.BLUR.4.png
#   inflating: blur/cactus.BLUR.5.png
#   inflating: blur/child_swimming.BLUR.1.png
#   inflating: blur/child_swimming.BLUR.2.png
#   inflating: blur/child_swimming.BLUR.3.png
#   inflating: blur/child_swimming.BLUR.4.png
#   inflating: blur/child_swimming.BLUR.5.png
#   inflating: blur/couple.BLUR.1.png
#   inflating: blur/couple.BLUR.2.png
#   inflating: blur/couple.BLUR.3.png
#   inflating: blur/couple.BLUR.4.png
#   inflating: blur/couple.BLUR.5.png
#   inflating: blur/elk.BLUR.1.png
#   inflating: blur/elk.BLUR.2.png
#   inflating: blur/elk.BLUR.3.png
#   inflating: blur/elk.BLUR.4.png
#   inflating: blur/elk.BLUR.5.png
#   inflating: blur/family.BLUR.1.png
#   inflating: blur/family.BLUR.2.png
#   inflating: blur/family.BLUR.3.png
#   inflating: blur/family.BLUR.4.png
#   inflating: blur/family.BLUR.5.png
#   inflating: blur/fisher.BLUR.1.png
#   inflating: blur/fisher.BLUR.2.png
#   inflating: blur/fisher.BLUR.3.png
#   inflating: blur/fisher.BLUR.4.png
#   inflating: blur/fisher.BLUR.5.png
#   inflating: blur/foxy.BLUR.1.png
#   inflating: blur/foxy.BLUR.2.png
#   inflating: blur/foxy.BLUR.3.png
#   inflating: blur/foxy.BLUR.4.png
#   inflating: blur/foxy.BLUR.5.png
#   inflating: blur/geckos.BLUR.1.png
#   inflating: blur/geckos.BLUR.2.png
#   inflating: blur/geckos.BLUR.3.png
#   inflating: blur/geckos.BLUR.4.png
#   inflating: blur/geckos.BLUR.5.png
#   inflating: blur/lady_liberty.BLUR.1.png
#   inflating: blur/lady_liberty.BLUR.2.png
#   inflating: blur/lady_liberty.BLUR.3.png
#   inflating: blur/lady_liberty.BLUR.4.png
#   inflating: blur/lady_liberty.BLUR.5.png
#   inflating: blur/lake.BLUR.1.png
#   inflating: blur/lake.BLUR.2.png
#   inflating: blur/lake.BLUR.3.png
#   inflating: blur/lake.BLUR.4.png
#   inflating: blur/lake.BLUR.5.png
#   inflating: blur/log_seaside.BLUR.1.png
#   inflating: blur/log_seaside.BLUR.2.png
#   inflating: blur/log_seaside.BLUR.3.png
#   inflating: blur/log_seaside.BLUR.4.png
#   inflating: blur/log_seaside.BLUR.5.png
#   inflating: blur/monument.BLUR.1.png
#   inflating: blur/monument.BLUR.2.png
#   inflating: blur/monument.BLUR.3.png
#   inflating: blur/monument.BLUR.4.png
#   inflating: blur/monument.BLUR.5.png
#   inflating: blur/native_american.BLUR.1.png
#   inflating: blur/native_american.BLUR.2.png
#   inflating: blur/native_american.BLUR.3.png
#   inflating: blur/native_american.BLUR.4.png
#   inflating: blur/native_american.BLUR.5.png
#   inflating: blur/redwood.BLUR.1.png
#   inflating: blur/redwood.BLUR.2.png
#   inflating: blur/redwood.BLUR.3.png
#   inflating: blur/redwood.BLUR.4.png
#   inflating: blur/redwood.BLUR.5.png
#   inflating: blur/roping.BLUR.1.png
#   inflating: blur/roping.BLUR.2.png
#   inflating: blur/roping.BLUR.3.png
#   inflating: blur/roping.BLUR.4.png
#   inflating: blur/roping.BLUR.5.png
#   inflating: blur/rushmore.BLUR.1.png
#   inflating: blur/rushmore.BLUR.2.png
#   inflating: blur/rushmore.BLUR.3.png
#   inflating: blur/rushmore.BLUR.4.png
#   inflating: blur/rushmore.BLUR.5.png
#   inflating: blur/shroom.BLUR.1.png
#   inflating: blur/shroom.BLUR.2.png
#   inflating: blur/shroom.BLUR.3.png
#   inflating: blur/shroom.BLUR.4.png
#   inflating: blur/shroom.BLUR.5.png
#   inflating: blur/snow_leaves.BLUR.1.png
#   inflating: blur/snow_leaves.BLUR.2.png
#   inflating: blur/snow_leaves.BLUR.3.png
#   inflating: blur/snow_leaves.BLUR.4.png
#   inflating: blur/snow_leaves.BLUR.5.png
#   inflating: blur/sunset_sparrow.BLUR.1.png
#   inflating: blur/sunset_sparrow.BLUR.2.png
#   inflating: blur/sunset_sparrow.BLUR.3.png
#   inflating: blur/sunset_sparrow.BLUR.4.png
#   inflating: blur/sunset_sparrow.BLUR.5.png
#   inflating: blur/sunsetcolor.BLUR.1.png
#   inflating: blur/sunsetcolor.BLUR.2.png
#   inflating: blur/sunsetcolor.BLUR.3.png
#   inflating: blur/sunsetcolor.BLUR.4.png
#   inflating: blur/sunsetcolor.BLUR.5.png
#   inflating: blur/swarm.BLUR.1.png
#   inflating: blur/swarm.BLUR.2.png
#   inflating: blur/swarm.BLUR.3.png
#   inflating: blur/swarm.BLUR.4.png
#   inflating: blur/swarm.BLUR.5.png
#   inflating: blur/trolley.BLUR.1.png
#   inflating: blur/trolley.BLUR.2.png
#   inflating: blur/trolley.BLUR.3.png
#   inflating: blur/trolley.BLUR.4.png
#   inflating: blur/trolley.BLUR.5.png
#   inflating: blur/turtle.BLUR.1.png
#   inflating: blur/turtle.BLUR.2.png
#   inflating: blur/turtle.BLUR.3.png
#   inflating: blur/turtle.BLUR.4.png
#   inflating: blur/turtle.BLUR.5.png
#   inflating: blur/veggies.BLUR.1.png
#   inflating: blur/veggies.BLUR.2.png
#   inflating: blur/veggies.BLUR.3.png
#   inflating: blur/veggies.BLUR.4.png
#   inflating: blur/veggies.BLUR.5.png
#   inflating: blur/woman.BLUR.1.png
#   inflating: blur/woman.BLUR.2.png
#   inflating: blur/woman.BLUR.3.png
#   inflating: contrast/turtle.contrast.1.png
#   inflating: contrast/turtle.contrast.2.png
#   inflating: contrast/turtle.contrast.3.png
#   inflating: contrast/turtle.contrast.4.png
#   inflating: contrast/turtle.contrast.5.png
#   inflating: contrast/veggies.contrast.1.png
#   inflating: contrast/veggies.contrast.2.png
#   inflating: contrast/veggies.contrast.3.png
#   inflating: contrast/veggies.contrast.4.png
#   inflating: contrast/veggies.contrast.5.png
#   inflating: contrast/woman.contrast.1.png
#   inflating: contrast/woman.contrast.2.png
#   inflating: contrast/woman.contrast.3.png
#   inflating: contrast/woman.contrast.4.png
#   inflating: contrast/woman.contrast.5.png
#   inflating: fnoise/1600.fnoise.1.png
#   inflating: fnoise/1600.fnoise.2.png
#   inflating: fnoise/1600.fnoise.3.png
#   inflating: fnoise/1600.fnoise.4.png
#   inflating: fnoise/1600.fnoise.5.png
#   inflating: fnoise/aerial_city.fnoise.1.png
#   inflating: fnoise/aerial_city.fnoise.2.png
#   inflating: fnoise/aerial_city.fnoise.3.png
#   inflating: fnoise/aerial_city.fnoise.4.png
#   inflating: fnoise/aerial_city.fnoise.5.png
#   inflating: fnoise/boston.fnoise.1.png
#   inflating: fnoise/boston.fnoise.2.png
#   inflating: fnoise/boston.fnoise.3.png
#   inflating: fnoise/boston.fnoise.4.png
#   inflating: fnoise/boston.fnoise.5.png
#   inflating: fnoise/bridge.fnoise.1.png
#   inflating: fnoise/bridge.fnoise.2.png
#   inflating: fnoise/bridge.fnoise.3.png
#   inflating: fnoise/bridge.fnoise.4.png
#   inflating: fnoise/bridge.fnoise.5.png
#   inflating: fnoise/butter_flower.fnoise.1.png
#   inflating: fnoise/butter_flower.fnoise.2.png
#   inflating: fnoise/butter_flower.fnoise.3.png
#   inflating: fnoise/butter_flower.fnoise.4.png
#   inflating: fnoise/butter_flower.fnoise.5.png
#   inflating: fnoise/cactus.fnoise.1.png
#   inflating: fnoise/cactus.fnoise.2.png
#   inflating: fnoise/cactus.fnoise.3.png
#   inflating: fnoise/cactus.fnoise.4.png
#   inflating: fnoise/cactus.fnoise.5.png
#   inflating: fnoise/child_swimming.fnoise.1.png
#   inflating: fnoise/child_swimming.fnoise.2.png
#   inflating: fnoise/child_swimming.fnoise.3.png
#   inflating: fnoise/child_swimming.fnoise.4.png
#   inflating: fnoise/child_swimming.fnoise.5.png
#   inflating: fnoise/couple.fnoise.1.png
#   inflating: fnoise/couple.fnoise.2.png
#   inflating: fnoise/couple.fnoise.3.png
#   inflating: fnoise/couple.fnoise.4.png
#   inflating: fnoise/couple.fnoise.5.png
#   inflating: fnoise/elk.fnoise.1.png
#   inflating: fnoise/elk.fnoise.2.png
#   inflating: fnoise/elk.fnoise.3.png
#   inflating: fnoise/elk.fnoise.4.png
#   inflating: fnoise/elk.fnoise.5.png
#   inflating: fnoise/family.fnoise.1.png
#   inflating: fnoise/family.fnoise.2.png
#   inflating: fnoise/family.fnoise.3.png
#   inflating: fnoise/family.fnoise.4.png
#   inflating: fnoise/family.fnoise.5.png
#   inflating: fnoise/fisher.fnoise.1.png
#   inflating: fnoise/fisher.fnoise.2.png
#   inflating: fnoise/fisher.fnoise.3.png
#   inflating: fnoise/fisher.fnoise.4.png
#   inflating: fnoise/fisher.fnoise.5.png
#   inflating: fnoise/foxy.fnoise.1.png
#   inflating: fnoise/foxy.fnoise.2.png
#   inflating: fnoise/foxy.fnoise.3.png
#   inflating: fnoise/foxy.fnoise.4.png
#   inflating: fnoise/foxy.fnoise.5.png
#   inflating: fnoise/geckos.fnoise.1.png
#   inflating: fnoise/geckos.fnoise.2.png
#   inflating: fnoise/geckos.fnoise.3.png
#   inflating: fnoise/geckos.fnoise.4.png
#   inflating: fnoise/geckos.fnoise.5.png
#   inflating: fnoise/lady_liberty.fnoise.1.png
#   inflating: fnoise/lady_liberty.fnoise.2.png
#   inflating: fnoise/lady_liberty.fnoise.3.png
#   inflating: fnoise/lady_liberty.fnoise.4.png
#   inflating: fnoise/lady_liberty.fnoise.5.png
#   inflating: fnoise/lake.fnoise.1.png
#   inflating: fnoise/lake.fnoise.2.png
#   inflating: fnoise/lake.fnoise.3.png
#   inflating: fnoise/lake.fnoise.4.png
#   inflating: fnoise/lake.fnoise.5.png
#   inflating: fnoise/log_seaside.fnoise.1.png
#   inflating: fnoise/log_seaside.fnoise.2.png
#   inflating: fnoise/log_seaside.fnoise.3.png
#   inflating: fnoise/log_seaside.fnoise.4.png
#   inflating: fnoise/log_seaside.fnoise.5.png
#   inflating: fnoise/monument.fnoise.1.png
#   inflating: fnoise/monument.fnoise.2.png
#   inflating: fnoise/monument.fnoise.3.png
#   inflating: fnoise/monument.fnoise.4.png
#   inflating: fnoise/monument.fnoise.5.png
#   inflating: fnoise/native_american.fnoise.1.png
#   inflating: fnoise/native_american.fnoise.2.png
#   inflating: fnoise/native_american.fnoise.3.png
#   inflating: fnoise/native_american.fnoise.4.png
#   inflating: fnoise/native_american.fnoise.5.png
#   inflating: fnoise/redwood.fnoise.1.png
#   inflating: fnoise/redwood.fnoise.2.png
#   inflating: fnoise/redwood.fnoise.3.png
#   inflating: fnoise/redwood.fnoise.4.png
#   inflating: fnoise/redwood.fnoise.5.png
#   inflating: fnoise/roping.fnoise.1.png
#   inflating: fnoise/roping.fnoise.2.png
#   inflating: fnoise/roping.fnoise.3.png
#   inflating: fnoise/roping.fnoise.4.png
#   inflating: fnoise/roping.fnoise.5.png
#   inflating: fnoise/rushmore.fnoise.1.png
#   inflating: fnoise/rushmore.fnoise.2.png
#   inflating: fnoise/rushmore.fnoise.3.png
#   inflating: fnoise/rushmore.fnoise.4.png
#   inflating: fnoise/rushmore.fnoise.5.png
#   inflating: fnoise/shroom.fnoise.1.png
#   inflating: fnoise/shroom.fnoise.2.png
#   inflating: fnoise/shroom.fnoise.3.png
#   inflating: fnoise/shroom.fnoise.4.png
#   inflating: fnoise/shroom.fnoise.5.png
#   inflating: fnoise/snow_leaves.fnoise.1.png
#   inflating: fnoise/snow_leaves.fnoise.2.png
#   inflating: fnoise/snow_leaves.fnoise.3.png
#   inflating: fnoise/snow_leaves.fnoise.4.png
#   inflating: fnoise/snow_leaves.fnoise.5.png
DISTORT_EXT = ['BLUR','contrast','fnoise', 'JPEG', 'jpeg2000']
Q_LEVELS = ['1','2','3','4','5']

from random import randint
import numpy as np
import cv2
import os

def load_imgs():
  images = {}
  images['orig'] = []
  for dist in DISTORT:
    images[dist] = {}
    for qlvl in Q_LEVELS:
      images[dist][qlvl] = []

  for f in [file for file in os.listdir() if file.endswith('.png')]:
    fname = os.path.splitext(f)[0]
    img_data = cv2.imread(f)
    img_data = cv2.cvtColor(img_data, cv2.COLOR_BGR2RGB)
    images['orig'].append(img_data)
    for dist, d_ext in zip(DISTORT, DISTORT_EXT):
      for qlvl in Q_LEVELS:
        f_path = dist+'/'+fname+'.'+d_ext+'.'+qlvl+'.png'
        img_data = cv2.imread(f_path)
        img_data = cv2.cvtColor(img_data, cv2.COLOR_BGR2RGB)
        images[dist][qlvl].append(img_data)
  return images

images = load_imgs()

print("Nr of img:",len(images['orig']))
# Out:
# Nr of img: 30

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import MultipleLocator

def plot_all(arr_of_images, patch_estimator=False):
  columns = 5
  spacing = 14.75
  minorLocator = MultipleLocator(spacing)
  fig = plt.figure(figsize=(40,20))
  for i, image in enumerate(arr_of_images):
    ax = fig.add_subplot(len(images) / columns + 1, columns, i + 1)
    if patch_estimator:
      ax.yaxis.set_minor_locator(minorLocator)
      ax.xaxis.set_minor_locator(minorLocator)
      ax.grid(which = 'minor')
    plt.imshow(image)
  plt.show()

# %%
#Print some stats

rand_idx = randint(0, len(images['orig'])-3)
plot_all(images['orig'][rand_idx:rand_idx+3])
plot_all(images['blur']['5'][rand_idx:rand_idx+3])
plot_all(images['contrast']['5'][rand_idx:rand_idx+3])

# %% [markdown]
# # Score Images
#
# apply the method suggested in [Learning without Human Scores for Blind Image Quality Assessment](https://www.cv-foundation.org/openaccess/content_cvpr_2013/papers/Xue_Learning_without_Human_2013_CVPR_paper.pdf)

# %% [markdown]
# ## Extract Patches and calculate {SSIM} score

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading https://files.pythonhosted.org/packages/7d/e6/19dfaff08fcbee7f3453e5b537e65a8364f1945f921a36d08be1e2ff3475/tqdm-4.24.0-py2.py3-none-any.whl (43kB)
#     100% |████████████████████████████████| 51kB 2.0MB/s
# Installing collected packages: tqdm
# Successfully installed tqdm-4.24.0

# %%
from skimage.measure import compare_ssim
from skimage.util.shape import view_as_windows
from tqdm import tqdm

WH=15
WINDOW_SHAPE = (WH,WH,3)
PATCH_COUNT = 1156 #TODO this should be automated somehow

def plot_patches(patches):
  w=10
  h=10
  fig=plt.figure(figsize=(8, 8))
  columns = 1
  rows = 1
  for i in range(1, columns*rows +1):
      img = patches[i-1]
      fig.add_subplot(rows, columns, i)
      plt.imshow(img)
  plt.show()

def extract_patches(img):
  patches = np.squeeze(view_as_windows(img, WINDOW_SHAPE,step=WH))
  patches = np.reshape(patches,(-1,15,15,3))
  return patches

dim_len, dim_dist, dim_q = len(images['orig']), len(DISTORT), len(Q_LEVELS);
test_len = dim_len

one_score = [[np.zeros(PATCH_COUNT) for x in range(dim_dist)] for y in range(dim_q)]
scores = [np.copy(one_score) for x in range(test_len)]

for i in tqdm(range(len(images['orig'][:test_len]))):
  img = images['orig'][i]
  orig_patches = extract_patches(img)
  for idist, dist in enumerate(DISTORT):
    for iqlvl, qlvl in enumerate(Q_LEVELS):
      dist_img = images[dist][qlvl][i]
      distorted_patches = extract_patches(dist_img)
      local_scores = np.zeros(PATCH_COUNT)
      for j in range(PATCH_COUNT):
        orig_patch = orig_patches[j]
        dist_patch = distorted_patches[j]
        (score, diff) = compare_ssim(orig_patch, dist_patch, full=True, multichannel=True)
        local_scores[j] = score
      scores[i][idist][iqlvl] = np.copy(local_scores)

#   plot_patches(orig_patches)
#   for patch in orig_patches:
#   (score, diff) = compare_ssim(dist_img, img, full=True, multichannel=True)
#   diff = (diff * 255).astype("uint8")
#   print("___")
#   print("SSIM: {}".format(score))
# Out:
# 100%|██████████| 30/30 [08:56<00:00, 17.90s/it]

# %% [markdown]
# ## Calculate the C constant (![alt text](https://latex.codecogs.com/gif.latex?c%20%3D%20%5Cfrac%7B%5Csum%20_%7Bi%5Cepsilon%20%5COmega%7DS_%7Bi%7D%20%7D%7B10*%5Csum%20_%7Bi%5Cepsilon%20%5COmega_%7Bp%7D%7DS_%7Bi%7D%7D))

# %%
def the_C_constant(batch):
  all_sum = sum(batch)
  percentile10 = np.percentile(batch,10)
  omega_p_sum = sum([i for i in batch if i <= percentile10])
  c = all_sum / (10 * omega_p_sum)
  return c
# the_C_constant(scores[0][0][0])

# %% [markdown]
# ## Histograms for scores

# %%
#Do some tests to check the scores

from mpl_toolkits.mplot3d import Axes3D

print(np.array(scores).shape)

def histogram(img_idx, img_dist, img_qual):
  print("comparing for {}".format(img_idx))
  print("(img-{} dist-{} qual-{})".format(img_idx, img_dist, img_qual))
  print(scores[img_idx][img_dist][img_qual])
  plt.hist(scores[img_idx][img_dist][img_qual], bins='auto')
  plt.show()
# Out:
# (30, 5, 5, 1156)

# %%
ri = randint(0,dim_len-1)
rd = randint(0,dim_dist-1)
rq = randint(0,dim_q-1)

for i in range(ri,ri+1):
  for d in range(rd,rd+1):
    for q in range(rq,rq+1):
      c = the_C_constant(scores[i][d][q])
      print(c)
      histogram(ri,rd,rq)
      plot_all([images['orig'][i],images['blur']['4'][i]])
# Out:
# 2.951822628756952
# comparing for 9
# (img-9 dist-3 qual-4)
# [0.95743134 0.94219335 0.94884582 ... 0.38238764 0.44664553 0.46505204]

# %% [markdown]
# ## Normalize scores

# %%
norm_scores = np.copy(scores)
for i in range(0,dim_len):
  for d in range(0,dim_dist):
    for q in range(0,dim_q):
      c = the_C_constant(scores[i][d][q])
      norm_scores[i][d][q][:] = [x / c for x in norm_scores[i][d][q]]

# %%
ri = randint(0,dim_len-1)
rd = randint(0,dim_dist-1)
rq = randint(0,dim_q-1)

print("(img-{} dist-{} qual-{})".format(ri, DISTORT[rd], Q_LEVELS[rq]))

plt.hist(scores[ri][rd][rq], alpha=0.5, label='Scores')
plt.hist(norm_scores[ri][rd][rq], alpha=0.5, label='Norm Scores')
plt.legend(loc='upper right')
plt.show()

plot_all([images['orig'][ri],images[DISTORT[rd]][Q_LEVELS[rq]][ri]])
# Out:
# (img-29 dist-blur qual-5)
